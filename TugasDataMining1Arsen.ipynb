# %%
#import pandas, numpy, matplotlib, serta seaborn 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
#import dataset

sns.set(style="whitegrid")
df = pd.read_csv ('C:/Users/acer/Downloads/archive/heart_disease_uci.csv')

# %%
#tampilkan 5 baris pertama dari dataset

print("- 5 baris pertama : ")
df.head()
# Out:
# - 5 baris pertama :
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# ...

# %%
#tampilkan 5 baris terakhir dari dataset

print("- 5 baris terakhir : ")
df.tail()
# Out:
# - 5 baris terakhir :
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# 918    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN    0
# 919    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN    1

# %%
#menunjukkan informasi dataset

print("\n Informasi Dataset : ")
df_info = pd.DataFrame({
    'Column' : df.columns,
    'Non-Null Count' : df.count().values,
    'Data Type' : df.dtypes.values
})
print(tabulate(df_info, headers='keys', tablefmt='pretty'))
# Out:
#  Informasi Dataset :
# +----+----------+----------------+-----------+
# |    |  Column  | Non-Null Count | Data Type |
# +----+----------+----------------+-----------+
# | 0  |    id    |      920       |   int64   |
# | 1  |   age    |      920       |   int64   |
# | 2  |   sex    |      920       |  object   |
# | 3  | dataset  |      920       |  object   |
# | 4  |    cp    |      920       |  object   |
# | 5  | trestbps |      861       |  float64  |
# | 6  |   chol   |      890       |  float64  |
# | 7  |   fbs    |      830       |  object   |
# | 8  | restecg  |      918       |  object   |
# | 9  |  thalch  |      865       |  float64  |
# | 10 |  exang   |      865       |  object   |
# | 11 | oldpeak  |      858       |  float64  |
# | 12 |  slope   |      611       |  object   |
# | 13 |    ca    |      309       |  float64  |
# | 14 |   thal   |      434       |  object   |
# | 15 |   num    |      920       |   int64   |
# ...

# %%
#Menampilkan nilai yang hilang pada dataset 

missing_values = df.isnull().sum().reset_index()
missing_values.columns = ['Column', 'Missing Values']
print('\n Nilai yang hilang : ')
print(tabulate(missing_values, headers='keys', tablefmt='pretty'))
# Out:
#  Nilai yang hilang :
# +----+----------+----------------+
# |    |  Column  | Missing Values |
# +----+----------+----------------+
# | 0  |    id    |       0        |
# | 1  |   age    |       0        |
# | 2  |   sex    |       0        |
# | 3  | dataset  |       0        |
# | 4  |    cp    |       0        |
# | 5  | trestbps |       59       |
# | 6  |   chol   |       30       |
# | 7  |   fbs    |       90       |
# | 8  | restecg  |       2        |
# | 9  |  thalch  |       55       |
# | 10 |  exang   |       55       |
# | 11 | oldpeak  |       62       |
# | 12 |  slope   |      309       |
# | 13 |    ca    |      611       |
# | 14 |   thal   |      486       |
# | 15 |   num    |       0        |
# +----+----------+----------------+

# %%
#Box plot untuk mendeteksi outliers

plt.figure(figsize=(10, 6))
sns.boxplot(data=df.select_dtypes(include=[np.number]))
plt.xticks(rotation=90)
plt.title('Box Plot untuk Variabel Nummerik')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Statistik deskriptifnya

print('\n Statistik Deskriptif : ')
print(tabulate(df.describe().reset_index(), headers='keys', tablefmt='pretty'))
# Out:
#  Statistik Deskriptif :
# +---+-------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |   | index |         id         |        age        |      trestbps      |        chol        |       thalch       |      oldpeak       |         ca         |        num         |
# +---+-------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | 0 | count |       920.0        |       920.0       |       861.0        |       890.0        |       865.0        |       858.0        |       309.0        |       920.0        |
# | 1 | mean  |       460.5        | 53.51086956521739 | 132.13240418118468 | 199.13033707865168 | 137.5456647398844  | 0.8787878787878788 | 0.6763754045307443 | 0.9956521739130435 |
# ...

# %%
#Menghitung mean, median, mode, standar deviasi, variansi, skewness beserta kurtosis

print("Menghitung mean, median, mode, standar deviasi, variansi, skewness beserta kurtosis")
numeric_cols = df.select_dtypes(include=[np.number]).columns
for col in numeric_cols:
    print(f"\nStatistik untuk {col} : ")
    print(f"Mean               : {df[col].mean()}")
    print(f"Median             : {df[col].median()}")
    print(f"Mode               : {df[col].mode()[0]}")
    print(f"Standar Deviasi    : {df[col].std()}")
    print(f"Variansi           : {df[col].var()}")
    print(f"Skewness           : {df[col].skew()}")
    print(f"Kurtosis           : {df[col].kurt()}")
    print("-------------------------------------------")
# Out:
# Menghitung mean, median, mode, standar deviasi, variansi, skewness beserta kurtosis
#
# Statistik untuk id :
# Mean               : 460.5
# Median             : 460.5
# Mode               : 1
# Standar Deviasi    : 265.72542219366215
# Variansi           : 70610.0
# Skewness           : 0.0
# Kurtosis           : -1.2
# -------------------------------------------
#
# Statistik untuk age :
# Mean               : 53.51086956521739
# Median             : 54.0
# Mode               : 54
# Standar Deviasi    : 9.424685209576857
# Variansi           : 88.82469129961679
# Skewness           : -0.195993861608106
# Kurtosis           : -0.3829298182845311
# -------------------------------------------
#
# Statistik untuk trestbps :
# Mean               : 132.13240418118468
# Median             : 130.0
# Mode               : 120.0
# Standar Deviasi    : 19.066069518587476
# Variansi           : 363.5150068876104
# Skewness           : 0.21333446967212508
# Kurtosis           : 2.958664416580538
# ...

# %%
#Menghitung korelasi antar variabel numerik

numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

#Membuat matriks korelasi
print("\n Matriks Korelasi : ")
print(tabulate(correlation_matrix.reset_index(), headers='keys', tablefmt='fancy_grid'))

#Membuat heatmap korelasi antara variabel
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5)
plt.title('Heatmap Korelasi Antar Variabel')
plt.show()
# Out:
#  Matriks Korelasi :
# ╒════╤══════════╤════════════╤════════════╤════════════╤════════════╤═══════════╤════════════╤════════════╤═══════════╕
# │    │ index    │         id │        age │   trestbps │       chol │    thalch │    oldpeak │         ca │       num │
# ╞════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪════════════╪════════════╪═══════════╡
# │  0 │ id       │  1         │  0.239301  │  0.0529237 │ -0.376936  │ -0.466427 │  0.0499302 │  0.0614335 │  0.273552 │
# ├────┼──────────┼────────────┼────────────┼────────────┼────────────┼───────────┼────────────┼────────────┼───────────┤
# │  1 │ age      │  0.239301  │  1         │  0.244253  │ -0.0862344 │ -0.365778 │  0.258243  │  0.370416  │  0.339596 │
# ├────┼──────────┼────────────┼────────────┼────────────┼────────────┼───────────┼────────────┼────────────┼───────────┤
# │  2 │ trestbps │  0.0529237 │  0.244253  │  1         │  0.0928532 │ -0.104899 │  0.161908  │  0.0937045 │  0.122291 │
# ...

# %%
#Menampilkan histogram untuk setiap variabel numerik

print("Histogram untuk setiap variabel numerik")
df.hist(bins=20, figsize=(15, 10))
plt.show()
# Out:
# Histogram untuk setiap variabel numerik

# %%
#Menampilkan box plot untuk setiap variabel numerik

print("Box plot untuk setiap variabel numerik")
df.plot(kind='box', subplots=True, layout=(4, 4), figsize=(15, 15), sharex=False, sharey=False)
plt.show()
# Out:
# Box plot untuk setiap variabel numerik

# %%
#Menampilkan scatter plot untuk pasangan variabel dengan korelasi tinggi

print("Scatter plot untuk pasangan variabel dengan korelasi tinggi")
sns.pairplot(df, hue='age')
plt.show()
# Out:
# Scatter plot untuk pasangan variabel dengan korelasi tinggi

# %%
# Menghitung matriks korelasi dan menemukan pasangan variabel dengan korelasi tertinggi
max_corr_pair = numeric_df.corr().abs().unstack().sort_values(ascending=False).drop_duplicates().index[1]

# Membuat scatter plot dengan garis regresi polinomial (order=2)
plt.figure(figsize=(8, 6))
sns.regplot(x=numeric_df[max_corr_pair[0]], y=numeric_df[max_corr_pair[1]], order=2, scatter_kws={'s': 50}, line_kws={"color":"red"})
plt.title(f'Scatter plot antara {max_corr_pair[0]} dan {max_corr_pair[1]} dengan garis regresi polinomial (Korelasi: {numeric_df.corr().loc[max_corr_pair[0], max_corr_pair[1]]:.2f})')
plt.xlabel(max_corr_pair[0])
plt.ylabel(max_corr_pair[1])
plt.show()

# %%
#Laporan singkat dari hasil analisis dataset UCI Heart Disease Data

report = f"""
Laporan:

Berdasarkan eksplorasi dan analisis data dari dataset Heart Disease Data di Kaggle, berikut adalah kesimpulan yang dapat diambil:

1. Distribusi yang Tidak Normal:
Beberapa variabel dalam dataset menunjukkan distribusi yang tidak normal.
Sebagai contoh, variabel age mungkin menunjukkan distribusi yang lebih condong ke usia yang lebih tua, yang mungkin disebabkan oleh fokus dataset pada individu dengan risiko penyakit jantung.
Distribusi variabel lain, seperti chol (kolesterol) dan trestbps (tekanan darah istirahat), juga dapat menunjukkan penyimpangan dari distribusi normal.

2. Korelasi Kuat Antar Variabel:
Dalam analisis korelasi, ditemukan bahwa variabel seperti age dan chol mungkin memiliki korelasi positif dengan keberadaan penyakit jantung (num), yang menunjukkan bahwa peningkatan usia dan kadar kolesterol mungkin meningkatkan risiko penyakit jantung.
Sebaliknya, variabel seperti thalach (detak jantung maksimal) mungkin menunjukkan korelasi negatif dengan penyakit jantung, yang berarti individu dengan detak jantung maksimal yang lebih rendah mungkin memiliki risiko yang lebih tinggi.

3. Outliers:
Analisis boxplot dan scatterplot dapat mengungkapkan adanya outliers dalam beberapa variabel, seperti chol dan trestbps.
Outliers ini bisa menjadi indikasi pasien dengan kondisi yang sangat tidak biasa atau mungkin juga kesalahan pengukuran.

4. Missing Values:
Ada kemungkinan terdapat nilai yang hilang (missing values) dalam beberapa kolom. 
Variabel seperti ca (jumlah pembuluh darah utama yang diwarnai oleh fluoroskopi) dan thal (status thalassemia) sering memiliki nilai hilang dalam dataset kesehatan. 
Ini bisa mempengaruhi analisis lebih lanjut dan perlu penanganan khusus, seperti imputasi atau penghapusan baris.

5. Penemuan Lain yang Signifikan:
Variabel cp (jenis nyeri dada) dan exang (exercise induced angina) tampaknya sangat berpengaruh dalam prediksi penyakit jantung. 
Misalnya, tipe nyeri dada seperti asymptomatic dan exang yang bernilai True sering dikaitkan dengan tingkat penyakit jantung yang lebih tinggi.
Penelitian juga dapat menyoroti bahwa faktor-faktor seperti jenis kelamin (sex) dan status kesehatan dasar (restecg, fbs) juga memainkan peran penting dalam memprediksi risiko penyakit jantung.

Kesimpulan Akhir:
Hasil dari eksplorasi dan analisis dataset menunjukkan bahwa penyakit jantung dipengaruhi oleh berbagai faktor yang dapat saling berinteraksi. 
Data yang tidak normal, outliers, dan nilai yang hilang semuanya harus dipertimbangkan dalam analisis lebih lanjut atau pembuatan model prediktif.
Korelasi yang kuat antara variabel tertentu mengindikasikan faktor risiko utama, yang penting untuk diperhatikan dalam konteks klinis dan pengambilan keputusan medis.
"""
#Tampilkan laporan
print(report)
# Out:
# Laporan:
#
# Berdasarkan eksplorasi dan analisis data dari dataset Heart Disease Data di Kaggle, berikut adalah kesimpulan yang dapat diambil:
#
# 1. Distribusi yang Tidak Normal:
# Beberapa variabel dalam dataset menunjukkan distribusi yang tidak normal.
# Sebagai contoh, variabel age mungkin menunjukkan distribusi yang lebih condong ke usia yang lebih tua, yang mungkin disebabkan oleh fokus dataset pada individu dengan risiko penyakit jantung.
# Distribusi variabel lain, seperti chol (kolesterol) dan trestbps (tekanan darah istirahat), juga dapat menunjukkan penyimpangan dari distribusi normal.
#
# 2. Korelasi Kuat Antar Variabel:
# Dalam analisis korelasi, ditemukan bahwa variabel seperti age dan chol mungkin memiliki korelasi positif dengan keberadaan penyakit jantung (num), yang menunjukkan bahwa peningkatan usia dan kadar kolesterol mungkin meningkatkan risiko penyakit jantung.
# ...
